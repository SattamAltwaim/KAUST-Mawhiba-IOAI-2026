# %% [markdown]
# ![KAUST Academy](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # Day 2 -- Lab 3: Challenge
#
# A telecommunications company is losing customers. Management wants a model that predicts which customers are likely to churn so the retention team can intervene early. The company has provided a dataset of 7,043 customer records with 21 attributes covering demographics, account information, and service usage.
#
# **The challenge:** At the bottom of this notebook you will find a model evaluation block. It expects four variables -- `X_train`, `X_test`, `y_train`, `y_test` -- where every value is numeric and there are no missing entries. The block trains two classifiers and reports their performance.
#
# Your job is to make that block run successfully and achieve an accuracy above 0.75. How you get there is entirely up to you. There are no step-by-step instructions.
#
# **Dataset:** Telco Customer Churn (7,043 records, 21 features, binary target: Churn)
#
# **Known issues with this dataset:**
# - The `TotalCharges` column contains hidden blank strings that prevent numeric conversion.
# - The `customerID` column is a unique identifier with no predictive value.
# - Several columns have only two or three unique values but are stored as strings.
# - The target classes are imbalanced.

# %%
# !pip install -q kagglehub

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (accuracy_score, f1_score, classification_report,
                             confusion_matrix, roc_curve, auc)
import os
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set_style('whitegrid')

# %%
import kagglehub
path = kagglehub.dataset_download('blastchar/telco-customer-churn')
csv_file = [f for f in os.listdir(path) if f.endswith('.csv')][0]
df = pd.read_csv(os.path.join(path, csv_file))
print(f"Shape: {df.shape}")
df.head()

# %% [markdown]
# ## Explore

# %%
#

# %%
#

# %%
#

# %%
#

# %% [markdown]
# ## Clean

# %%
#

# %%
#

# %%
#

# %%
#

# %% [markdown]
# ## Feature Engineering

# %%
#

# %%
#

# %%
#

# %% [markdown]
# ## Prepare for Modeling
#
# Split into X/y, encode, scale, and create train/test sets. The model block below expects: X_train, X_test, y_train, y_test (all numeric, no NaNs).

# %%
#

# %%
#

# %%
#

# %% [markdown]
# ---
# ## Model Evaluation (do not modify)
#
# The cells below train two classifiers on your prepared data and report performance metrics. If you see errors, your data preparation has issues -- go back and fix them.

# %%
lr = LogisticRegression(max_iter=1000, random_state=42)
lr.fit(X_train, y_train)
lr_pred = lr.predict(X_test)
lr_prob = lr.predict_proba(X_test)[:, 1]

rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)
rf_prob = rf.predict_proba(X_test)[:, 1]

print("Models trained successfully.")

# %%
print("=" * 60)
print("LOGISTIC REGRESSION")
print("=" * 60)
print(f"Accuracy: {accuracy_score(y_test, lr_pred):.4f}")
print(f"F1 Score: {f1_score(y_test, lr_pred):.4f}")
print()
print(classification_report(y_test, lr_pred))

print("=" * 60)
print("RANDOM FOREST")
print("=" * 60)
print(f"Accuracy: {accuracy_score(y_test, rf_pred):.4f}")
print(f"F1 Score: {f1_score(y_test, rf_pred):.4f}")
print()
print(classification_report(y_test, rf_pred))

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax, pred, name in zip(axes, [lr_pred, rf_pred], ['Logistic Regression', 'Random Forest']):
    cm = confusion_matrix(y_test, pred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax,
                xticklabels=['No Churn', 'Churn'],
                yticklabels=['No Churn', 'Churn'])
    ax.set_title(f'{name} -- Confusion Matrix')
    ax.set_ylabel('Actual')
    ax.set_xlabel('Predicted')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))

for prob, name, color in zip([lr_prob, rf_prob],
                              ['Logistic Regression', 'Random Forest'],
                              ['steelblue', 'darkorange']):
    fpr, tpr, _ = roc_curve(y_test, prob)
    roc_auc = auc(fpr, tpr)
    ax.plot(fpr, tpr, color=color, lw=2, label=f'{name} (AUC = {roc_auc:.3f})')

ax.plot([0, 1], [0, 1], 'k--', lw=1)
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curves')
ax.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %%
best_accuracy = max(accuracy_score(y_test, lr_pred), accuracy_score(y_test, rf_pred))
print(f"\nBest accuracy achieved: {best_accuracy:.4f}")
assert best_accuracy > 0.75, "Accuracy below 0.75 -- revisit your data preparation and feature engineering."
print("Challenge passed.")
