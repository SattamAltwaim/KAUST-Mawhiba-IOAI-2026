# %% [markdown]
# ![KAUST Academy](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # Day 3 -- Lab 1: Regression & Loss Functions
#
# A physics lab has recorded data from a spring experiment — applying various forces and measuring the resulting extension. Hooke's Law predicts a linear relationship (extension = k × force + offset), but real measurements are noisy. You will build a linear regression model from scratch using only NumPy, implement the two most important loss functions, visualize how they guide learning, and run gradient descent to find the best-fit line.
#
# **Approach:** We use synthetic data with a known ground truth so you can verify your implementation. At the end, you will apply sklearn's LinearRegression to a real multi-feature dataset.

# %% [markdown]
# ---
# ## Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ---
# ## Data Generation

# %%
np.random.seed(42)
n = 200
X = np.random.uniform(0, 10, n)
y = 3 * X + 7 + np.random.normal(0, 2, n)   # true: w=3, b=7
print(f"Generated {n} points.  True relationship: y = 3x + 7 + noise")

# %% [markdown]
# ---
# ## Task 1: Scatter Plot
#
# Before fitting any model, visualize the data to confirm the linear trend.
#
# **TODO:** Create a scatter plot of X vs y. Label axes as 'Force (N)' and 'Extension (mm)'. Add a title.

# %%
# Your code here

# %% [markdown]
# ---
# ## Task 2: Implement MSE
#
# Mean Squared Error is the most common regression loss. It squares every residual, heavily penalizing large errors.
#
# **TODO:** Write a function `mse(y_true, y_pred)` that computes MSE using only NumPy. Test it: if `y_true = [3, -0.5, 2]` and `y_pred = [2.5, 0.0, 2.1]`, the MSE should be approximately 0.1167.

# %%
# Your code here

# %% [markdown]
# ---
# ## Task 3: Implement MAE
#
# Mean Absolute Error uses the absolute value of residuals instead of squaring them, making it less sensitive to outliers.
#
# **TODO:** Write a function `mae(y_true, y_pred)` that computes MAE using only NumPy. Test it on the same example — MAE should be approximately 0.2667.

# %%
# Your code here

# %% [markdown]
# ---
# ## Task 4: Manual Predictions
#
# Before automating anything, build intuition. Try several (w, b) pairs, compute predictions y_pred = w*X + b, and measure the loss.
#
# **TODO:** Create a list of at least 5 (w, b) pairs (e.g., (1,1), (2,5), (3,7), (4,10), (3,5)). For each, compute MSE and MAE. Print a table and identify which pair gives the lowest MSE.

# %%
# Your code here

# %% [markdown]
# ---
# ## Task 5: Loss Landscape
#
# Visualize how the loss changes across all possible (w, b) values. This 'loss landscape' reveals the bowl-shaped surface that gradient descent navigates.
#
# **TODO:** Create a grid of w values from 0 to 6 and b values from 0 to 14 (50 steps each). Compute MSE at every grid point. Create two plots side by side: a 3D surface plot (using `plot_surface`) and a 2D contour plot (using `contourf`). Mark the true minimum (w=3, b=7) on the contour plot.

# %%
# Your code here

# %% [markdown]
# ---
# ## Task 6: Gradient Derivation
#
# Gradient descent needs the partial derivatives of MSE with respect to w and b. For predictions ŷ = wX + b and MSE = (1/n)Σ(y - ŷ)², the gradients are:
#
# ∂MSE/∂w = -(2/n) Σ (y - ŷ) · X
#
# ∂MSE/∂b = -(2/n) Σ (y - ŷ)
#
# **TODO:** Write a function `compute_gradients(X, y, w, b)` that returns (dw, db). Test it at (w=0, b=0) — the gradient should point toward the true minimum.

# %%
# Your code here

# %% [markdown]
# ---
# ## Task 7: Gradient Descent Training Loop
#
# Now combine everything into a training loop. Start with random weights, compute the loss and gradients, update weights, repeat.
#
# **TODO:** Initialize w=0, b=0. Set learning_rate=0.01 and run 200 iterations. At each step, compute gradients, update w and b, and record the MSE. Print the final w, b and compare to the true values (3, 7).

# %%
# Your code here

# %% [markdown]
# ---
# ## Task 8: Loss Curve
#
# A declining loss curve is the signature of successful training. If the curve plateaus, the model has converged; if it oscillates, the learning rate may be too high.
#
# **TODO:** Plot the loss_history from Task 7. Label axes, add a title. In a comment, describe what you observe about convergence speed.

# %%
# Your code here

# %% [markdown]
# ---
# ## Task 9: MSE vs MAE Robustness
#
# MSE squares errors, so a single outlier can dominate the loss. MAE treats all errors linearly, making it more robust. Let's see this in action.
#
# **TODO:** Add 10 extreme outliers to the dataset (e.g., y_outliers = 50 for small X values). Train two models with gradient descent — one minimizing MSE and one minimizing MAE (for MAE, the gradient of |r| is sign(r), so dw = -(1/n)Σ sign(y-ŷ)·X and db = -(1/n)Σ sign(y-ŷ)). Plot both fitted lines on the corrupted data. Compare slopes and intercepts to the true values.

# %%
# Your code here

# %% [markdown]
# ---
# ## Task 10: Multi-Feature Regression with sklearn
#
# Real datasets have many features. Now apply what you've learned using sklearn's LinearRegression on the California Housing dataset (8 features, predicting median house value).
#
# **TODO:** Load the California Housing dataset with `fetch_california_housing()`. Split into train/test (80/20, random_state=42). Standardize features with StandardScaler. Fit a LinearRegression. Print the R² score. Create a scatter plot of predicted vs actual values with a diagonal reference line.

# %%
# Your code here

# %% [markdown]
# ---
# ## Conclusion
#
# You have implemented linear regression from scratch:
# - **MSE** squares residuals — fast convergence but sensitive to outliers.
# - **MAE** uses absolute residuals — slower convergence but robust to outliers.
# - **Gradient descent** navigates the loss landscape to find the optimal weights.
# - On a real multi-feature dataset, sklearn's LinearRegression achieves the same result in one line.
#
# Next lab: we flip from regression to classification and meet a new loss function — cross-entropy.
