# %% [markdown]
# ![KAUST Academy](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # Day 5 -- Lab 2: Classical ML Model Shootout
#
# A hospital wants to predict which patients are at risk of **diabetes** using clinical measurements from 800 patients. In Lab 1 you learned the core scikit-learn API (transformers, splitters, predictors). Now you will put those skills to work: train **five different classifiers** and let **cross-validation** decide the winner.
#
# | Stage | Goal |
# |---|---|
# | Quick Data Prep | Impute, encode, scale -- no deep EDA |
# | Train Five Models | Lasso LR, KNN, SVM, XGBoost, Random Forest |
# | Cross-Validation | 5-fold stratified CV to compare all models fairly |
# | Best Model Eval | Confusion matrix + classification report |
#
# **Theme: "No Free Lunch"** -- there is no single algorithm that is always best. The only way to find the best model for *your* data is to try many and measure.

# %%
# !pip install xgboost -q

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, classification_report, ConfusionMatrixDisplay
)
from xgboost import XGBClassifier

plt.rcParams['figure.dpi'] = 120

# %% [markdown]
# ---
# # Part 1 -- Quick Data Prep

# %% [markdown]
# ## Task 1: Load and Inspect
#
# Load the CSV, print the shape, and call `.info()`. Separate features (`X`) from the target (`y = diabetes`).

# %%
# Your code here

# %% [markdown]
# ## Task 2: Impute Missing Values
#
# Check for missing values with `df.isnull().sum()`. Impute:
# - **Numeric columns** -- fill with the **median**
# - **Categorical columns** -- fill with the **mode** (most frequent value)

# %%
# Your code here

# %% [markdown]
# ## Task 3: One-Hot Encode Categoricals
#
# Use `pd.get_dummies()` to one-hot encode the categorical columns (`gender`, `smoking_history`). Set `drop_first=True` to avoid the dummy-variable trap.

# %%
# Your code here

# %% [markdown]
# ## Task 4: Scale Features
#
# Apply `StandardScaler` to **all** columns of `X`. Store the result as a NumPy array.

# %%
# Your code here

# %% [markdown]
# ## Task 5: Stratified Train/Test Split
#
# Split into 80% train / 20% test with `stratify=y` so the class ratio is preserved in both sets.

# %%
# Your code here

# %% [markdown]
# ---
# # Part 2 -- Train Five Models
#
# For each model: instantiate, fit on the training set, predict on the test set, and print the accuracy.

# %% [markdown]
# ## Task 6: Lasso Logistic Regression
#
# Use `LogisticRegression(penalty='l1', solver='saga', max_iter=5000)`.

# %%
# Your code here

# %% [markdown]
# ## Task 7: K-Nearest Neighbors
#
# Use `KNeighborsClassifier(n_neighbors=5)`.

# %%
# Your code here

# %% [markdown]
# ## Task 8: Support Vector Machine
#
# Use `SVC(kernel='rbf', probability=True)`.

# %%
# Your code here

# %% [markdown]
# ## Task 9: Gradient Boosting (XGBoost)
#
# Use `XGBClassifier(n_estimators=100, use_label_encoder=False, eval_metric='logloss')`.

# %%
# Your code here

# %% [markdown]
# ## Task 10: Random Forest
#
# Use `RandomForestClassifier(n_estimators=100, random_state=42)`.

# %%
# Your code here

# %% [markdown]
# ---
# # Part 3 -- Cross-Validation Showdown

# %% [markdown]
# ## Task 11: 5-Fold Stratified Cross-Validation
#
# Use `cross_val_score` to run 5-fold stratified CV on each model. Collect **accuracy** and **F1** scores separately.
#
# **Hint:** Loop over a dictionary of `{name: model}` pairs. Call `cross_val_score` twice per model -- once with `scoring='accuracy'` and once with `scoring='f1'`.

# %%
# Your code here

# %% [markdown]
# ## Task 12: Bar Chart Comparison
#
# Create a grouped bar chart with model names on the x-axis and two bars per model (CV Accuracy and CV F1). Include error bars showing the standard deviation.

# %%
# Your code here

# %% [markdown]
# ---
# # Part 4 -- Best Model Deep Evaluation

# %% [markdown]
# ## Task 13: Pick the Best Model
#
# Based on cross-validation results, identify the best model. Retrain it on the **full training set** and predict on the test set.

# %%
# Your code here

# %% [markdown]
# ## Task 14: Confusion Matrix and Classification Report
#
# Display a confusion matrix heatmap (`ConfusionMatrixDisplay`) and print the full `classification_report`.

# %%
# Your code here

# %% [markdown]
# ---
# # Part 5 -- Reflection

# %% [markdown]
# ## Task 15: Reflect
#
# Answer these questions in the cell below:
#
# 1. Which model won the cross-validation showdown?
# 2. Was it the most complex model? The simplest?
# 3. How does this relate to the "No Free Lunch" theorem?

# %% [markdown]
# *Your answers here*

# %% [markdown]
# ---
# ## Conclusion
#
# You trained five very different classifiers on the same diabetes dataset and used cross-validation to compare them fairly. Key takeaways:
#
# | What you practiced | Why it matters |
# |---|---|
# | Multiple model families | Different inductive biases suit different data |
# | Cross-validation | Honest estimate of generalization, not a lucky split |
# | Stratified splitting | Preserves class balance in every fold |
# | Confusion matrix | Accuracy alone hides mistakes on the minority class |
#
# Tomorrow you will re-solve this same problem using a **neural network in PyTorch** -- same data, new tool.
